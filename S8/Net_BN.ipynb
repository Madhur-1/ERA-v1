# %% [markdown]
# # CIFAR-10 dataset classification
# ## Net 1

# %% [markdown]
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.

# %% [markdown]
# # Importing basic dependencies

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# del model
import torch
import torch.nn as nn
import torch.optim as optim
from Utilities.model import Net1
from Utilities.utils import train, test
import torch.nn.functional as F
from torchsummary import summary

torch.manual_seed(1)

# %%
CLASSES = ("Airplane", "Automobile", "Bird", "Cat", "Deer", "Dog", "Frog", "Horse", "Ship", "Truck")

# %% [markdown]
# # Model Initialization & Summary

# %%
device = torch.device("mps")
model = Net1(dropout_percentage=0.05, norm="bn")
summary(model, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             448
#        BatchNorm2d-2           [-1, 16, 32, 32]              32
#               ReLU-3           [-1, 16, 32, 32]               0
#            Dropout-4           [-1, 16, 32, 32]               0
#             Conv2d-5           [-1, 32, 32, 32]           4,640
#        BatchNorm2d-6           [-1, 32, 32, 32]              64
#               ReLU-7           [-1, 32, 32, 32]               0
#            Dropout-8           [-1, 32, 32, 32]               0
#             Conv2d-9           [-1, 16, 32, 32]             528
#         MaxPool2d-10           [-1, 16, 16, 16]               0
#            Conv2d-11           [-1, 16, 16, 16]           2,320
#       BatchNorm2d-12           [-1, 16, 16, 16]              32
#              ReLU-13           [-1, 16, 16, 16]               0
#           Dropout-14           [-1, 16, 16, 16]               0
#            Conv2d-15           [-1, 32, 16, 16]           4,640
#       BatchNorm2d-16           [-1, 32, 16, 16]              64
#              ReLU-17           [-1, 32, 16, 16]               0
#           Dropout-18           [-1, 32, 16, 16]               0
#            Conv2d-19           [-1, 32, 16, 16]           9,248
#            Conv2d-20           [-1, 32, 16, 16]             544
#       BatchNorm2d-21           [-1, 32, 16, 16]              64
#              ReLU-22           [-1, 32, 16, 16]               0
#           Dropout-23           [-1, 32, 16, 16]               0
#            Conv2d-24           [-1, 16, 16, 16]             528
#         MaxPool2d-25             [-1, 16, 8, 8]               0
#            Conv2d-26             [-1, 16, 8, 8]           2,320
#       BatchNorm2d-27             [-1, 16, 8, 8]              32
#              ReLU-28             [-1, 16, 8, 8]               0
#           Dropout-29             [-1, 16, 8, 8]               0
#            Conv2d-30             [-1, 32, 8, 8]           4,640
#       BatchNorm2d-31             [-1, 32, 8, 8]              64
#              ReLU-32             [-1, 32, 8, 8]               0
#           Dropout-33             [-1, 32, 8, 8]               0
#            Conv2d-34             [-1, 32, 8, 8]           9,248
#            Conv2d-35             [-1, 32, 8, 8]             544
#       BatchNorm2d-36             [-1, 32, 8, 8]              64
#              ReLU-37             [-1, 32, 8, 8]               0
#           Dropout-38             [-1, 32, 8, 8]               0
# AdaptiveAvgPool2d-39             [-1, 32, 1, 1]               0
#            Conv2d-40             [-1, 10, 1, 1]             330
# ================================================================
# Total params: 40,394
# Trainable params: 40,394
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 2.56
# Params size (MB): 0.15
# Estimated Total Size (MB): 2.72
# ----------------------------------------------------------------

# %% [markdown]
# # Dataset & Dataloaders

# %%
from Utilities.transforms import train_transforms, test_transforms

# %%
from Utilities.dataset import get_dataloaders

batch_size = 64

kwargs = {'batch_size': batch_size, 'shuffle': True, 'num_workers': 4, 'pin_memory': True}
train_loader, test_loader = get_dataloaders(train_transforms=train_transforms, test_transforms=test_transforms, **kwargs)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Data Exploration

# %%
from Utilities.visualize import plot_data_samples, plot_class_label_counts

# plot_class_label_counts(train_loader, classes=CLASSES)
plot_data_samples(train_loader, classes=CLASSES)

# %% [markdown]
# # Training

# %%
model = Net1(dropout_percentage=0.02, norm="bn").to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=8, gamma=0.1, verbose=True)
# New Line
criterion = F.nll_loss
num_epochs = 20

# Data to plot accuracy and loss graphs
train_losses = []
test_losses = []
train_acc = []
test_acc = []

for epoch in range(1, num_epochs+1):
  print(f'Epoch {epoch}')
  train_accs, train_losses = train(model, device, train_loader, optimizer, criterion)
  test_accs, test_losses = test(model, device, test_loader, criterion)
  scheduler.step()
# Out:
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 1
# Train: 100% Loss=1.5282 Batch_id=781 Accuracy=41.24
# Test set: Average loss: 1.4219, Accuracy: 4930/10000 (49.30%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 2
# Train: 100% Loss=1.0656 Batch_id=781 Accuracy=58.35
# Test set: Average loss: 1.0347, Accuracy: 6325/10000 (63.25%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 3
# Train: 100% Loss=0.9304 Batch_id=781 Accuracy=63.82
# Test set: Average loss: 1.0175, Accuracy: 6391/10000 (63.91%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 4
# Train: 100% Loss=0.7330 Batch_id=781 Accuracy=67.29
# Test set: Average loss: 0.9206, Accuracy: 6714/10000 (67.14%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 5
# Train: 100% Loss=1.1641 Batch_id=781 Accuracy=69.87
# Test set: Average loss: 0.8133, Accuracy: 7131/10000 (71.31%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 6
# Train: 100% Loss=0.6233 Batch_id=781 Accuracy=71.79
# Test set: Average loss: 0.7956, Accuracy: 7223/10000 (72.23%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 7
# Train: 100% Loss=1.0510 Batch_id=781 Accuracy=73.26
# Test set: Average loss: 0.7703, Accuracy: 7355/10000 (73.55%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 8
# Train: 100% Loss=1.0817 Batch_id=781 Accuracy=74.32
# Test set: Average loss: 0.6940, Accuracy: 7593/10000 (75.93%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 9
# Train: 100% Loss=0.6313 Batch_id=781 Accuracy=77.87
# Test set: Average loss: 0.6273, Accuracy: 7834/10000 (78.34%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 10
# Train: 100% Loss=0.3977 Batch_id=781 Accuracy=78.32
# Test set: Average loss: 0.6217, Accuracy: 7818/10000 (78.18%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 11
# Train: 100% Loss=1.1543 Batch_id=781 Accuracy=78.61
# Test set: Average loss: 0.6141, Accuracy: 7878/10000 (78.78%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 12
# Train: 100% Loss=0.8015 Batch_id=781 Accuracy=78.89
# Test set: Average loss: 0.6150, Accuracy: 7891/10000 (78.91%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 13
# Train: 100% Loss=0.4738 Batch_id=781 Accuracy=79.17
# Test set: Average loss: 0.6162, Accuracy: 7869/10000 (78.69%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 14
# Train: 100% Loss=0.9129 Batch_id=781 Accuracy=79.40
# Test set: Average loss: 0.6109, Accuracy: 7902/10000 (79.02%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 15
# Train: 100% Loss=0.6512 Batch_id=781 Accuracy=79.52
# Test set: Average loss: 0.6119, Accuracy: 7900/10000 (79.00%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 16
# Train: 100% Loss=0.3366 Batch_id=781 Accuracy=79.40
# Test set: Average loss: 0.6061, Accuracy: 7922/10000 (79.22%)
#
# Adjusting learning rate of group 0 to 1.0000e-04.
# Epoch 17
# Train: 100% Loss=0.6678 Batch_id=781 Accuracy=79.92
# Test set: Average loss: 0.6013, Accuracy: 7915/10000 (79.15%)
#
# Adjusting learning rate of group 0 to 1.0000e-04.
# Epoch 18
# Train: 100% Loss=1.0888 Batch_id=781 Accuracy=80.17
# Test set: Average loss: 0.5960, Accuracy: 7957/10000 (79.57%)
#
# Adjusting learning rate of group 0 to 1.0000e-04.
# Epoch 19
# Train: 100% Loss=0.5132 Batch_id=781 Accuracy=79.89
# Test set: Average loss: 0.5981, Accuracy: 7939/10000 (79.39%)
#
# Adjusting learning rate of group 0 to 1.0000e-04.
# Epoch 20
# Train: 100% Loss=0.7281 Batch_id=781 Accuracy=80.27
# Test set: Average loss: 0.6027, Accuracy: 7939/10000 (79.39%)
#
# Adjusting learning rate of group 0 to 1.0000e-04.

# %%
import pandas as pd
bn_df = pd.DataFrame({'Train Acc': train_accs, 'Test Acc': test_accs, 'Train Loss': train_losses, 'Test Loss': test_losses})
bn_df.to_csv('Store/BN_training.csv', index=False)

# %%
import pandas as pd
bn_train = pd.read_csv("Store/BN_training.csv")
bn_train
train_accs = bn_train['Train Acc'].tolist()
test_accs = bn_train['Test Acc'].tolist()
train_losses = bn_train['Train Loss'].tolist()
test_losses = bn_train['Test Loss'].tolist()

# %%
from Utilities.visualize import plot_model_training_curves

plot_model_training_curves(train_accs=train_accs, test_accs=test_accs, train_losses=train_losses, test_losses=test_losses)

# %% [markdown]
# # Model Analysis

# %%
from Utilities.utils import get_all_and_incorrect_preds
from Utilities.visualize import plot_confusion_matrix

all_preds, all_labels, incorrect = get_all_and_incorrect_preds(model=model, loader=test_loader, device=device)
plot_confusion_matrix(all_labels, all_preds, classes=CLASSES)

# %%
from Utilities.visualize import plot_incorrect_preds

plot_incorrect_preds(incorrect, classes=CLASSES)
# Out:
# Total Incorrect Predictions 2061
