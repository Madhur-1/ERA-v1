# %% [markdown]
# # CIFAR-10 dataset classification
# ## Net 1

# %% [markdown]
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.

# %% [markdown]
# # Importing basic dependencies

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# del model
import torch
import torch.nn as nn
import torch.optim as optim
from Utilities.model import Net1
from Utilities.utils import train, test
import torch.nn.functional as F
from torchsummary import summary

torch.manual_seed(1)

# %%
CLASSES = ("Airplane", "Automobile", "Bird", "Cat", "Deer", "Dog", "Frog", "Horse", "Ship", "Truck")

# %% [markdown]
# # Model Initialization & Summary

# %%
device = torch.device("mps")
model = Net1(dropout_percentage=0.02, norm="gn", num_groups=4)
summary(model, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             448
#          GroupNorm-2           [-1, 16, 32, 32]              32
#               ReLU-3           [-1, 16, 32, 32]               0
#            Dropout-4           [-1, 16, 32, 32]               0
#             Conv2d-5           [-1, 32, 32, 32]           4,640
#          GroupNorm-6           [-1, 32, 32, 32]              64
#               ReLU-7           [-1, 32, 32, 32]               0
#            Dropout-8           [-1, 32, 32, 32]               0
#             Conv2d-9           [-1, 16, 32, 32]             528
#         MaxPool2d-10           [-1, 16, 16, 16]               0
#            Conv2d-11           [-1, 16, 16, 16]           2,320
#         GroupNorm-12           [-1, 16, 16, 16]              32
#              ReLU-13           [-1, 16, 16, 16]               0
#           Dropout-14           [-1, 16, 16, 16]               0
#            Conv2d-15           [-1, 32, 16, 16]           4,640
#         GroupNorm-16           [-1, 32, 16, 16]              64
#              ReLU-17           [-1, 32, 16, 16]               0
#           Dropout-18           [-1, 32, 16, 16]               0
#            Conv2d-19           [-1, 32, 16, 16]           9,248
#            Conv2d-20           [-1, 32, 16, 16]             544
#         GroupNorm-21           [-1, 32, 16, 16]              64
#              ReLU-22           [-1, 32, 16, 16]               0
#           Dropout-23           [-1, 32, 16, 16]               0
#            Conv2d-24           [-1, 16, 16, 16]             528
#         MaxPool2d-25             [-1, 16, 8, 8]               0
#            Conv2d-26             [-1, 16, 8, 8]           2,320
#         GroupNorm-27             [-1, 16, 8, 8]              32
#              ReLU-28             [-1, 16, 8, 8]               0
#           Dropout-29             [-1, 16, 8, 8]               0
#            Conv2d-30             [-1, 32, 8, 8]           4,640
#         GroupNorm-31             [-1, 32, 8, 8]              64
#              ReLU-32             [-1, 32, 8, 8]               0
#           Dropout-33             [-1, 32, 8, 8]               0
#            Conv2d-34             [-1, 32, 8, 8]           9,248
#            Conv2d-35             [-1, 32, 8, 8]             544
#         GroupNorm-36             [-1, 32, 8, 8]              64
#              ReLU-37             [-1, 32, 8, 8]               0
#           Dropout-38             [-1, 32, 8, 8]               0
# AdaptiveAvgPool2d-39             [-1, 32, 1, 1]               0
#            Conv2d-40             [-1, 10, 1, 1]             330
# ================================================================
# Total params: 40,394
# Trainable params: 40,394
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 2.56
# Params size (MB): 0.15
# Estimated Total Size (MB): 2.72
# ----------------------------------------------------------------

# %% [markdown]
# # Dataset & Dataloaders

# %%
from Utilities.transforms import train_transforms, test_transforms

# %%
from Utilities.dataset import get_dataloaders

batch_size = 64

kwargs = {'batch_size': batch_size, 'shuffle': True, 'num_workers': 4, 'pin_memory': True}
train_loader, test_loader = get_dataloaders(train_transforms=train_transforms, test_transforms=test_transforms, **kwargs)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Data Exploration

# %%
from Utilities.visualize import plot_data_samples, plot_class_label_counts

# plot_class_label_counts(train_loader, classes=CLASSES)
plot_data_samples(train_loader, classes=CLASSES)

# %% [markdown]
# # Training

# %%
model = Net1(dropout_percentage=0.0, norm="gn", num_groups=4).to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1, verbose=True)
# New Line
criterion = F.nll_loss
num_epochs = 20

for epoch in range(1, num_epochs+1):
  print(f'Epoch {epoch}')
  train_accs, train_losses = train(model, device, train_loader, optimizer, criterion)
  test_accs, test_losses = test(model, device, test_loader, criterion)
  scheduler.step()
# Out:
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 1
# Train: 100% Loss=1.3055 Batch_id=781 Accuracy=26.42
# Test set: Average loss: 1.6368, Accuracy: 3826/10000 (38.26%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 2
# Train: 100% Loss=1.4839 Batch_id=781 Accuracy=42.60
# Test set: Average loss: 1.3132, Accuracy: 5120/10000 (51.20%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 3
# Train: 100% Loss=0.5472 Batch_id=781 Accuracy=51.88
# Test set: Average loss: 1.2761, Accuracy: 5441/10000 (54.41%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 4
# Train: 100% Loss=0.7574 Batch_id=781 Accuracy=57.38
# Test set: Average loss: 1.0818, Accuracy: 6116/10000 (61.16%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 5
# Train: 100% Loss=1.0332 Batch_id=781 Accuracy=61.66
# Test set: Average loss: 0.9731, Accuracy: 6526/10000 (65.26%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 6
# Train: 100% Loss=1.1959 Batch_id=781 Accuracy=64.41
# Test set: Average loss: 0.8968, Accuracy: 6847/10000 (68.47%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 7
# Train: 100% Loss=0.9988 Batch_id=781 Accuracy=66.79
# Test set: Average loss: 0.8734, Accuracy: 6872/10000 (68.72%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 8
# Train: 100% Loss=0.5959 Batch_id=781 Accuracy=72.51
# Test set: Average loss: 0.7742, Accuracy: 7254/10000 (72.54%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 9
# Train: 100% Loss=0.8172 Batch_id=781 Accuracy=73.35
# Test set: Average loss: 0.7676, Accuracy: 7277/10000 (72.77%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 10
# Train: 100% Loss=0.6785 Batch_id=781 Accuracy=73.53
# Test set: Average loss: 0.7707, Accuracy: 7270/10000 (72.70%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 11
# Train: 100% Loss=0.8017 Batch_id=781 Accuracy=73.77
# Test set: Average loss: 0.7576, Accuracy: 7380/10000 (73.80%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 12
# Train: 100% Loss=1.1065 Batch_id=781 Accuracy=74.56
# Test set: Average loss: 0.7530, Accuracy: 7326/10000 (73.26%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 13
# Train: 100% Loss=0.5904 Batch_id=781 Accuracy=74.75
# Test set: Average loss: 0.7472, Accuracy: 7356/10000 (73.56%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 14
# Train: 100% Loss=0.6747 Batch_id=781 Accuracy=74.89
# Test set: Average loss: 0.7317, Accuracy: 7419/10000 (74.19%)
#
# Adjusting learning rate of group 0 to 1.0000e-04.
# Epoch 15
# Train: 100% Loss=0.5306 Batch_id=781 Accuracy=76.03
# Test set: Average loss: 0.7233, Accuracy: 7452/10000 (74.52%)
#
# Adjusting learning rate of group 0 to 1.0000e-04.
# Epoch 16
# Train: 100% Loss=0.4783 Batch_id=781 Accuracy=75.86
# Test set: Average loss: 0.7230, Accuracy: 7452/10000 (74.52%)
#
# Adjusting learning rate of group 0 to 1.0000e-04.
# Epoch 17
# Train: 100% Loss=0.3052 Batch_id=781 Accuracy=76.20
# Test set: Average loss: 0.7217, Accuracy: 7482/10000 (74.82%)
#
# Adjusting learning rate of group 0 to 1.0000e-04.
# Epoch 18
# Train: 100% Loss=0.9270 Batch_id=781 Accuracy=76.28
# Test set: Average loss: 0.7208, Accuracy: 7470/10000 (74.70%)
#
# Adjusting learning rate of group 0 to 1.0000e-04.
# Epoch 19
# Train: 100% Loss=0.3725 Batch_id=781 Accuracy=76.26
# Test set: Average loss: 0.7210, Accuracy: 7480/10000 (74.80%)
#
# Adjusting learning rate of group 0 to 1.0000e-04.
# Epoch 20
# Train: 100% Loss=0.1887 Batch_id=781 Accuracy=76.18
# Test set: Average loss: 0.7206, Accuracy: 7484/10000 (74.84%)
#
# Adjusting learning rate of group 0 to 1.0000e-04.

# %%
import pandas as pd
gn_df = pd.DataFrame({'Train Acc': train_accs, 'Test Acc': test_accs, 'Train Loss': train_losses, 'Test Loss': test_losses})
gn_df.to_csv('Store/GN_training.csv', index=False)

# %%
from Utilities.visualize import plot_model_training_curves

plot_model_training_curves(train_accs=train_accs, test_accs=test_accs, train_losses=train_losses, test_losses=test_losses)

# %% [markdown]
# # Model Analysis

# %%
from Utilities.utils import get_all_and_incorrect_preds
from Utilities.visualize import plot_confusion_matrix

all_preds, all_labels, incorrect = get_all_and_incorrect_preds(model=model, loader=test_loader, device=device)
plot_confusion_matrix(all_labels, all_preds, classes=CLASSES)

# %%
from Utilities.visualize import plot_incorrect_preds

plot_incorrect_preds(incorrect, classes=CLASSES)
# Out:
# Total Incorrect Predictions 2516
