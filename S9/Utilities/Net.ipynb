# %% [markdown]
# # CIFAR-10 dataset classification
# ## Net 1

# %% [markdown]
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.

# %% [markdown]
# # Importing basic dependencies

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# del model
import torch
import torch.nn as nn
import torch.optim as optim
from Utilities.model import Net
from Utilities.utils import train, test
import torch.nn.functional as F
from torchsummary import summary

torch.manual_seed(1)

# %%
CLASSES = ("Airplane", "Automobile", "Bird", "Cat", "Deer", "Dog", "Frog", "Horse", "Ship", "Truck")

# %% [markdown]
# # Model Initialization & Summary

# %%
device = torch.device("mps")
model = Net(dropout_percentage=0.05, norm="bn")
summary(model, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 24, 32, 32]             672
#        BatchNorm2d-2           [-1, 24, 32, 32]              48
#               ReLU-3           [-1, 24, 32, 32]               0
#            Dropout-4           [-1, 24, 32, 32]               0
#             Conv2d-5           [-1, 44, 32, 32]           9,548
#        BatchNorm2d-6           [-1, 44, 32, 32]              88
#               ReLU-7           [-1, 44, 32, 32]               0
#            Dropout-8           [-1, 44, 32, 32]               0
#             Conv2d-9           [-1, 64, 16, 16]          25,408
#       BatchNorm2d-10           [-1, 64, 16, 16]             128
#              ReLU-11           [-1, 64, 16, 16]               0
#           Dropout-12           [-1, 64, 16, 16]               0
#            Conv2d-13           [-1, 24, 16, 16]          13,848
#       BatchNorm2d-14           [-1, 24, 16, 16]              48
#              ReLU-15           [-1, 24, 16, 16]               0
#           Dropout-16           [-1, 24, 16, 16]               0
#            Conv2d-17           [-1, 44, 16, 16]           9,548
#       BatchNorm2d-18           [-1, 44, 16, 16]              88
#              ReLU-19           [-1, 44, 16, 16]               0
#           Dropout-20           [-1, 44, 16, 16]               0
#            Conv2d-21           [-1, 44, 16, 16]           2,860
#            Conv2d-22             [-1, 64, 8, 8]          25,408
#       BatchNorm2d-23             [-1, 64, 8, 8]             128
#              ReLU-24             [-1, 64, 8, 8]               0
#           Dropout-25             [-1, 64, 8, 8]               0
#            Conv2d-26             [-1, 24, 8, 8]          13,848
#       BatchNorm2d-27             [-1, 24, 8, 8]              48
#              ReLU-28             [-1, 24, 8, 8]               0
#           Dropout-29             [-1, 24, 8, 8]               0
#            Conv2d-30             [-1, 44, 8, 8]           9,548
#       BatchNorm2d-31             [-1, 44, 8, 8]              88
#              ReLU-32             [-1, 44, 8, 8]               0
#           Dropout-33             [-1, 44, 8, 8]               0
#            Conv2d-34             [-1, 44, 8, 8]           2,860
#            Conv2d-35             [-1, 64, 6, 6]          25,408
#       BatchNorm2d-36             [-1, 64, 6, 6]             128
#              ReLU-37             [-1, 64, 6, 6]               0
#           Dropout-38             [-1, 64, 6, 6]               0
#            Conv2d-39             [-1, 24, 6, 6]          13,848
#       BatchNorm2d-40             [-1, 24, 6, 6]              48
#              ReLU-41             [-1, 24, 6, 6]               0
#           Dropout-42             [-1, 24, 6, 6]               0
#            Conv2d-43             [-1, 44, 6, 6]           9,548
#       BatchNorm2d-44             [-1, 44, 6, 6]              88
#              ReLU-45             [-1, 44, 6, 6]               0
#           Dropout-46             [-1, 44, 6, 6]               0
#            Conv2d-47             [-1, 44, 6, 6]           2,860
#            Conv2d-48             [-1, 44, 6, 6]             440
#            Conv2d-49             [-1, 64, 6, 6]           2,880
#       BatchNorm2d-50             [-1, 64, 6, 6]             128
#              ReLU-51             [-1, 64, 6, 6]               0
#           Dropout-52             [-1, 64, 6, 6]               0
# AdaptiveMaxPool2d-53             [-1, 64, 1, 1]               0
#            Conv2d-54             [-1, 10, 1, 1]             650
# ================================================================
# Total params: 170,238
# Trainable params: 170,238
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.76
# Params size (MB): 0.65
# Estimated Total Size (MB): 4.42
# ----------------------------------------------------------------

# %% [markdown]
# # Dataset & Dataloaders

# %%
from Utilities.transforms import train_transforms, test_transforms

# %%
from Utilities.dataset import get_dataloaders

batch_size = 64

kwargs = {'batch_size': batch_size, 'shuffle': True, 'num_workers': 4, 'pin_memory': True}
train_loader, test_loader = get_dataloaders(train_transforms=train_transforms, test_transforms=test_transforms, **kwargs)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Data Exploration

# %%
from Utilities.visualize import plot_data_samples, plot_class_label_counts

# plot_class_label_counts(train_loader, classes=CLASSES)
plot_data_samples(train_loader, classes=CLASSES)

# %% [markdown]
# # Training

# %%
model = Net(dropout_percentage=0.02, norm="bn").to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=8, gamma=0.1, verbose=True)
# New Line
criterion = F.nll_loss
num_epochs = 20

# Data to plot accuracy and loss graphs
train_losses = []
test_losses = []
train_accs = []
test_accs = []

for epoch in range(1, num_epochs+1):
  print(f'Epoch {epoch}')
  train_accs, train_losses = train(model, device, train_loader, optimizer, criterion, train_losses, train_accs)
  test_accs, test_losses = test(model, device, test_loader, criterion, test_losses, test_accs)
  scheduler.step()
# Out:
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 1
# Train: 100% Loss=2.0114 Batch_id=781 Accuracy=41.22
# Test set: Average loss: 1.3351, Accuracy: 5162/10000 (51.62%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 2
# Train: 100% Loss=1.4140 Batch_id=781 Accuracy=58.96
# Test set: Average loss: 0.9896, Accuracy: 6504/10000 (65.04%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 3
# Train: 100% Loss=0.7126 Batch_id=781 Accuracy=67.68
# Test set: Average loss: 0.7586, Accuracy: 7335/10000 (73.35%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 4
# Train: 100% Loss=0.9864 Batch_id=781 Accuracy=72.89
# Test set: Average loss: 0.6848, Accuracy: 7638/10000 (76.38%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 5
# Train: 100% Loss=1.1559 Batch_id=781 Accuracy=75.91
# Test set: Average loss: 0.5994, Accuracy: 7905/10000 (79.05%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 6
# Train: 100% Loss=0.4431 Batch_id=781 Accuracy=77.79
# Test set: Average loss: 0.6273, Accuracy: 7849/10000 (78.49%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 7
# Train: 100% Loss=0.3826 Batch_id=781 Accuracy=79.71
# Test set: Average loss: 0.5655, Accuracy: 8082/10000 (80.82%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 8
# Train: 100% Loss=0.5673 Batch_id=781 Accuracy=80.68
# Test set: Average loss: 0.5515, Accuracy: 8079/10000 (80.79%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 9
# Train: 100% Loss=0.2331 Batch_id=781 Accuracy=84.21
# Test set: Average loss: 0.4422, Accuracy: 8479/10000 (84.79%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 10
# Train: 100% Loss=0.4524 Batch_id=781 Accuracy=84.98
# Test set: Average loss: 0.4334, Accuracy: 8532/10000 (85.32%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 11
# Train: 100% Loss=0.5496 Batch_id=781 Accuracy=85.23
# Test set: Average loss: 0.4273, Accuracy: 8564/10000 (85.64%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 12
# Train: 100% Loss=1.3494 Batch_id=781 Accuracy=85.62
# Test set: Average loss: 0.4251, Accuracy: 8551/10000 (85.51%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 13
# Train: 100% Loss=0.3239 Batch_id=781 Accuracy=86.08
# Test set: Average loss: 0.4229, Accuracy: 8572/10000 (85.72%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 14
# Train: 100% Loss=0.5772 Batch_id=781 Accuracy=86.25
# Test set: Average loss: 0.4190, Accuracy: 8576/10000 (85.76%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 15
# Train: 100% Loss=0.1114 Batch_id=781 Accuracy=86.38
# Test set: Average loss: 0.4191, Accuracy: 8609/10000 (86.09%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 16
# Train: 100% Loss=0.4572 Batch_id=781 Accuracy=86.49
# Test set: Average loss: 0.4143, Accuracy: 8619/10000 (86.19%)
#
# Adjusting learning rate of group 0 to 1.0000e-04.
# Epoch 17
# Train: 100% Loss=0.4817 Batch_id=781 Accuracy=86.87
# Test set: Average loss: 0.4112, Accuracy: 8615/10000 (86.15%)
#
# Adjusting learning rate of group 0 to 1.0000e-04.
# Epoch 18
# Train: 100% Loss=0.6740 Batch_id=781 Accuracy=87.01
# Test set: Average loss: 0.4108, Accuracy: 8617/10000 (86.17%)
#
# Adjusting learning rate of group 0 to 1.0000e-04.
# Epoch 19
# Train: 100% Loss=0.1665 Batch_id=781 Accuracy=87.03
# Test set: Average loss: 0.4107, Accuracy: 8614/10000 (86.14%)
#
# Adjusting learning rate of group 0 to 1.0000e-04.
# Epoch 20
# Train: 100% Loss=0.6085 Batch_id=781 Accuracy=87.10
# Test set: Average loss: 0.4101, Accuracy: 8630/10000 (86.30%)
#
# Adjusting learning rate of group 0 to 1.0000e-04.

# %%
import pandas as pd
bn_df = pd.DataFrame({'Train Acc': train_accs, 'Test Acc': test_accs, 'Train Loss': train_losses, 'Test Loss': test_losses})
bn_df.to_csv('Store/training_stats.csv', index=False)

# %%
import pandas as pd
bn_train = pd.read_csv("Store/training_stats.csv")
bn_train
train_accs = bn_train['Train Acc'].tolist()
test_accs = bn_train['Test Acc'].tolist()
train_losses = bn_train['Train Loss'].tolist()
test_losses = bn_train['Test Loss'].tolist()

# %%
from Utilities.visualize import plot_model_training_curves

plot_model_training_curves(train_accs=train_accs, test_accs=test_accs, train_losses=train_losses, test_losses=test_losses)

# %% [markdown]
# # Model Analysis

# %%
from Utilities.utils import get_all_and_incorrect_preds
from Utilities.visualize import plot_confusion_matrix

all_preds, all_labels, incorrect = get_all_and_incorrect_preds(model=model, loader=test_loader, device=device)
plot_confusion_matrix(all_labels, all_preds, classes=CLASSES)

# %%
from Utilities.visualize import plot_incorrect_preds

plot_incorrect_preds(incorrect, classes=CLASSES)
# Out:
# Total Incorrect Predictions 1370
